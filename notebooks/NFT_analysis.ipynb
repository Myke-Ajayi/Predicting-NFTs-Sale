# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
parse_dates = ['listing_date','asset_contract.created_date', 'collection.created_date']
nft_sale_df = pd.read_csv('../nftsale.csv', low_memory=False, parse_dates=parse_dates)

# %%
nft_sale_df.head(5)
# Out:
#    Unnamed: 0        id token_id  num_sales background_color  \
# 0           0  44596334        1      14377              NaN
# 1           1  48159964      888       9533              NaN
# 2           2  76676445        0       8007              NaN
# 3           6  62163700    10004       5089              NaN
# 4           7  55436079        2       4704              NaN
#
#                                            image_url  \
# 0  https://lh3.googleusercontent.com/9GgkzN-7si-y...
# 1  https://lh3.googleusercontent.com/G_6AOl7ChtSg...
# 2  https://lh3.googleusercontent.com/AzJqhKOP2m_n...
# 3  https://lh3.googleusercontent.com/TgZhu3HfmExk...
# 4  https://lh3.googleusercontent.com/FIjcBiS0BxSQ...
#
#                                    image_preview_url  \
# 0  https://lh3.googleusercontent.com/9GgkzN-7si-y...
# 1  https://lh3.googleusercontent.com/G_6AOl7ChtSg...
# 2  https://lh3.googleusercontent.com/AzJqhKOP2m_n...
# 3  https://lh3.googleusercontent.com/TgZhu3HfmExk...
# 4  https://lh3.googleusercontent.com/FIjcBiS0BxSQ...
#
#                                  image_thumbnail_url  \
# 0  https://lh3.googleusercontent.com/9GgkzN-7si-y...
# 1  https://lh3.googleusercontent.com/G_6AOl7ChtSg...
# 2  https://lh3.googleusercontent.com/AzJqhKOP2m_n...
# 3  https://lh3.googleusercontent.com/TgZhu3HfmExk...
# 4  https://lh3.googleusercontent.com/FIjcBiS0BxSQ...
#
#                                   image_original_url  \
# 0  https://arweave.net/nhjGl6alIKUbS9MmkYRCaf1Mjj...
# 1  https://arweave.net/9qj1idiU1jXl7--f1YEqKue0Ze...
# 2      https://alethea.ai/media/pods/pod_level_1.jpg
# 3  https://ipfs.io/ipfs/QmSMSXt8Jxp4sXfpDozc9b18q...
# 4  https://ipfs.io/ipfs/QmWHCA2afX8y8NiRZYw5HXqyv...
#
#                                        animation_url  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2  https://storage.opensea.io/files/cf2893753c932...  ...
# 3  https://storage.opensea.io/files/11aafa7a8752c...  ...
# 4  https://storage.opensea.io/files/0fe49558d94fc...  ...
#
#   collection.display_data.images last_sale transfer_fee_payment_token.id  \
# 0                            NaN       NaN                           NaN
# 1                            NaN       NaN                           NaN
# 2                            NaN       NaN                           NaN
# 3                            NaN       NaN                           NaN
# 4                            NaN       NaN                           NaN
#
#   transfer_fee_payment_token.symbol transfer_fee_payment_token.address  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    transfer_fee_payment_token.image_url transfer_fee_payment_token.name  \
# 0                                   NaN                             NaN
# 1                                   NaN                             NaN
# 2                                   NaN                             NaN
# 3                                   NaN                             NaN
# 4                                   NaN                             NaN
#
#   transfer_fee_payment_token.decimals transfer_fee_payment_token.eth_price  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#    transfer_fee_payment_token.usd_price
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
# [5 rows x 130 columns]

# %%
list(nft_sale_df.columns )
# Out:
# ['Unnamed: 0',
#  'id',
#  'token_id',
#  'num_sales',
#  'background_color',
#  'image_url',
#  'image_preview_url',
#  'image_thumbnail_url',
#  'image_original_url',
#  'animation_url',
#  'animation_original_url',
#  'name',
#  'description',
#  'external_link',
#  'permalink',
#  'decimals',
#  'token_metadata',
#  'sell_orders',
#  'traits',
#  'top_bid',
#  'listing_date',
#  'is_presale',
#  'transfer_fee_payment_token',
#  'transfer_fee',
#  'asset_contract.address',
#  'asset_contract.asset_contract_type',
#  'asset_contract.created_date',
#  'asset_contract.name',
#  'asset_contract.nft_version',
#  'asset_contract.opensea_version',
#  'asset_contract.owner',
#  'asset_contract.schema_name',
#  'asset_contract.symbol',
#  'asset_contract.total_supply',
#  'asset_contract.description',
#  'asset_contract.external_link',
#  'asset_contract.image_url',
#  'asset_contract.default_to_fiat',
#  'asset_contract.dev_buyer_fee_basis_points',
#  'asset_contract.dev_seller_fee_basis_points',
#  'asset_contract.only_proxied_transfers',
#  'asset_contract.opensea_buyer_fee_basis_points',
#  'asset_contract.opensea_seller_fee_basis_points',
#  'asset_contract.buyer_fee_basis_points',
#  'asset_contract.seller_fee_basis_points',
#  'asset_contract.payout_address',
#  'collection.banner_image_url',
#  'collection.chat_url',
#  'collection.created_date',
#  'collection.default_to_fiat',
#  'collection.description',
#  'collection.dev_buyer_fee_basis_points',
#  'collection.dev_seller_fee_basis_points',
#  'collection.discord_url',
#  'collection.display_data.card_display_style',
#  'collection.external_url',
#  'collection.featured',
#  'collection.featured_image_url',
#  'collection.hidden',
#  'collection.safelist_request_status',
#  'collection.image_url',
#  'collection.is_subject_to_whitelist',
#  'collection.large_image_url',
#  'collection.medium_username',
#  'collection.name',
#  'collection.only_proxied_transfers',
#  'collection.opensea_buyer_fee_basis_points',
#  'collection.opensea_seller_fee_basis_points',
#  'collection.payout_address',
#  'collection.require_email',
#  'collection.short_description',
#  'collection.slug',
#  'collection.telegram_url',
#  'collection.twitter_username',
#  'collection.instagram_username',
#  'collection.wiki_url',
#  'owner.user.username',
#  'owner.profile_img_url',
#  'owner.address',
#  'owner.config',
#  'creator.user.username',
#  'creator.profile_img_url',
#  'creator.address',
#  'creator.config',
#  'last_sale.asset.token_id',
#  'last_sale.asset.decimals',
#  'last_sale.asset_bundle',
#  'last_sale.event_type',
#  'last_sale.event_timestamp',
#  'last_sale.auction_type',
#  'last_sale.total_price',
#  'last_sale.payment_token.id',
#  'last_sale.payment_token.symbol',
#  'last_sale.payment_token.address',
#  'last_sale.payment_token.image_url',
#  'last_sale.payment_token.name',
#  'last_sale.payment_token.decimals',
#  'last_sale.payment_token.eth_price',
#  'last_sale.payment_token.usd_price',
#  'last_sale.transaction.block_hash',
#  'last_sale.transaction.block_number',
#  'last_sale.transaction.from_account.user.username',
#  'last_sale.transaction.from_account.profile_img_url',
#  'last_sale.transaction.from_account.address',
#  'last_sale.transaction.from_account.config',
#  'last_sale.transaction.id',
#  'last_sale.transaction.timestamp',
#  'last_sale.transaction.to_account.user.username',
#  'last_sale.transaction.to_account.profile_img_url',
#  'last_sale.transaction.to_account.address',
#  'last_sale.transaction.to_account.config',
#  'last_sale.transaction.transaction_hash',
#  'last_sale.transaction.transaction_index',
#  'last_sale.created_date',
#  'last_sale.quantity',
#  'creator',
#  'last_sale.transaction.from_account.user',
#  'last_sale.transaction.to_account.user',
#  'owner.user',
#  'creator.user',
#  'collection.display_data.images',
#  'last_sale',
#  'transfer_fee_payment_token.id',
#  'transfer_fee_payment_token.symbol',
#  'transfer_fee_payment_token.address',
#  'transfer_fee_payment_token.image_url',
#  'transfer_fee_payment_token.name',
#  'transfer_fee_payment_token.decimals',
#  'transfer_fee_payment_token.eth_price',
#  'transfer_fee_payment_token.usd_price']

# %%
# the data has 130 columns and we do not need all of them.
nft_sale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14461 entries, 0 to 14460
# Columns: 130 entries, Unnamed: 0 to transfer_fee_payment_token.usd_price
# dtypes: bool(9), datetime64[ns](3), float64(25), int64(13), object(80)
# memory usage: 13.5+ MB

# %%
nft_sale_df.shape
# Out:
# (14461, 130)

# %%
# check for null values 
nft_sale_df['background_color'].isna().sum()
# Out:
# 14346

# %%
# check for percentages for null values 
for column in list(nft_sale_df.columns):
    print(f"{nft_sale_df[str(column)].isnull().sum()/len(nft_sale_df):.2%} of {column} is null")
# Out:
# 0.00% of Unnamed: 0 is null
# 0.00% of id is null
# 0.00% of token_id is null
# 0.00% of num_sales is null
# 99.20% of background_color is null
# 4.69% of image_url is null
# 4.69% of image_preview_url is null
# 4.69% of image_thumbnail_url is null
# 59.27% of image_original_url is null
# 73.54% of animation_url is null
# 73.28% of animation_original_url is null
# 5.28% of name is null
# 27.61% of description is null
# 70.80% of external_link is null
# 0.00% of permalink is null
# 72.34% of decimals is null
# 59.71% of token_metadata is null
# 56.81% of sell_orders is null
# 0.00% of traits is null
# 100.00% of top_bid is null
# 100.00% of listing_date is null
# 0.00% of is_presale is null
# 100.00% of transfer_fee_payment_token is null
# 0.00% of transfer_fee is null
# 0.00% of asset_contract.address is null
# 0.00% of asset_contract.asset_contract_type is null
# 0.00% of asset_contract.created_date is null
# 0.00% of asset_contract.name is null
# 67.26% of asset_contract.nft_version is null
# 45.45% of asset_contract.opensea_version is null
# 19.38% of asset_contract.owner is null
# 0.00% of asset_contract.schema_name is null
# 9.06% of asset_contract.symbol is null
# 90.82% of asset_contract.total_supply is null
# 59.59% of asset_contract.description is null
# 60.73% of asset_contract.external_link is null
# 59.10% of asset_contract.image_url is null
# 0.00% of asset_contract.default_to_fiat is null
# 0.00% of asset_contract.dev_buyer_fee_basis_points is null
# 0.00% of asset_contract.dev_seller_fee_basis_points is null
# 0.00% of asset_contract.only_proxied_transfers is null
# 0.00% of asset_contract.opensea_buyer_fee_basis_points is null
# 0.00% of asset_contract.opensea_seller_fee_basis_points is null
# 0.00% of asset_contract.buyer_fee_basis_points is null
# 0.00% of asset_contract.seller_fee_basis_points is null
# 67.94% of asset_contract.payout_address is null
# 15.34% of collection.banner_image_url is null
# 99.99% of collection.chat_url is null
# 0.00% of collection.created_date is null
# 0.00% of collection.default_to_fiat is null
# 12.88% of collection.description is null
# 0.00% of collection.dev_buyer_fee_basis_points is null
# 0.00% of collection.dev_seller_fee_basis_points is null
# 57.92% of collection.discord_url is null
# 4.35% of collection.display_data.card_display_style is null
# 43.02% of collection.external_url is null
# 0.00% of collection.featured is null
# 24.69% of collection.featured_image_url is null
# 0.00% of collection.hidden is null
# 0.00% of collection.safelist_request_status is null
# 7.22% of collection.image_url is null
# 0.00% of collection.is_subject_to_whitelist is null
# 17.78% of collection.large_image_url is null
# 85.35% of collection.medium_username is null
# 0.00% of collection.name is null
# 0.00% of collection.only_proxied_transfers is null
# 0.00% of collection.opensea_buyer_fee_basis_points is null
# 0.00% of collection.opensea_seller_fee_basis_points is null
# 20.81% of collection.payout_address is null
# 0.00% of collection.require_email is null
# 99.91% of collection.short_description is null
# 0.00% of collection.slug is null
# 86.52% of collection.telegram_url is null
# 24.59% of collection.twitter_username is null
# 77.73% of collection.instagram_username is null
# 99.84% of collection.wiki_url is null
# 23.71% of owner.user.username is null
# 0.00% of owner.profile_img_url is null
# 0.00% of owner.address is null
# 99.35% of owner.config is null
# 16.38% of creator.user.username is null
# 1.42% of creator.profile_img_url is null
# 1.42% of creator.address is null
# 91.29% of creator.config is null
# 71.07% of last_sale.asset.token_id is null
# 99.80% of last_sale.asset.decimals is null
# 100.00% of last_sale.asset_bundle is null
# 71.07% of last_sale.event_type is null
# 71.07% of last_sale.event_timestamp is null
# 95.64% of last_sale.auction_type is null
# 71.07% of last_sale.total_price is null
# 71.07% of last_sale.payment_token.id is null
# 71.07% of last_sale.payment_token.symbol is null
# 71.07% of last_sale.payment_token.address is null
# 71.07% of last_sale.payment_token.image_url is null
# 71.07% of last_sale.payment_token.name is null
# 71.07% of last_sale.payment_token.decimals is null
# 71.11% of last_sale.payment_token.eth_price is null
# 71.11% of last_sale.payment_token.usd_price is null
# 71.07% of last_sale.transaction.block_hash is null
# 71.07% of last_sale.transaction.block_number is null
# 77.40% of last_sale.transaction.from_account.user.username is null
# 71.07% of last_sale.transaction.from_account.profile_img_url is null
# 71.07% of last_sale.transaction.from_account.address is null
# 99.18% of last_sale.transaction.from_account.config is null
# 71.07% of last_sale.transaction.id is null
# 71.07% of last_sale.transaction.timestamp is null
# 75.49% of last_sale.transaction.to_account.user.username is null
# 71.07% of last_sale.transaction.to_account.profile_img_url is null
# 71.07% of last_sale.transaction.to_account.address is null
# 75.49% of last_sale.transaction.to_account.config is null
# 71.07% of last_sale.transaction.transaction_hash is null
# 71.07% of last_sale.transaction.transaction_index is null
# 71.07% of last_sale.created_date is null
# 71.29% of last_sale.quantity is null
# 100.00% of creator is null
# 100.00% of last_sale.transaction.from_account.user is null
# 100.00% of last_sale.transaction.to_account.user is null
# 100.00% of owner.user is null
# 100.00% of creator.user is null
# 91.34% of collection.display_data.images is null
# 100.00% of last_sale is null
# 99.87% of transfer_fee_payment_token.id is null
# 99.87% of transfer_fee_payment_token.symbol is null
# 99.87% of transfer_fee_payment_token.address is null
# 99.87% of transfer_fee_payment_token.image_url is null
# 99.87% of transfer_fee_payment_token.name is null
# 99.87% of transfer_fee_payment_token.decimals is null
# 99.87% of transfer_fee_payment_token.eth_price is null
# 99.87% of transfer_fee_payment_token.usd_price is null

# %% [markdown]
# There are quite missing values in this data, however just by analysisng the columns there some
# columns, that should have missing values because it differentiates between NFTs that are resold or just selling for the first time.

# %%
for x in nft_sale_df.columns:
    print(f'{x} has a {nft_sale_df[x].dtypes} type')
# Out:
# Unnamed: 0 has a int64 type
# id has a int64 type
# token_id has a object type
# num_sales has a int64 type
# background_color has a object type
# image_url has a object type
# image_preview_url has a object type
# image_thumbnail_url has a object type
# image_original_url has a object type
# animation_url has a object type
# animation_original_url has a object type
# name has a object type
# description has a object type
# external_link has a object type
# permalink has a object type
# decimals has a float64 type
# token_metadata has a object type
# sell_orders has a object type
# traits has a object type
# top_bid has a float64 type
# listing_date has a datetime64[ns] type
# is_presale has a bool type
# transfer_fee_payment_token has a float64 type
# transfer_fee has a object type
# asset_contract.address has a object type
# asset_contract.asset_contract_type has a object type
# asset_contract.created_date has a datetime64[ns] type
# asset_contract.name has a object type
# asset_contract.nft_version has a object type
# asset_contract.opensea_version has a object type
# asset_contract.owner has a float64 type
# asset_contract.schema_name has a object type
# asset_contract.symbol has a object type
# asset_contract.total_supply has a float64 type
# asset_contract.description has a object type
# asset_contract.external_link has a object type
# asset_contract.image_url has a object type
# asset_contract.default_to_fiat has a bool type
# asset_contract.dev_buyer_fee_basis_points has a int64 type
# asset_contract.dev_seller_fee_basis_points has a int64 type
# asset_contract.only_proxied_transfers has a bool type
# asset_contract.opensea_buyer_fee_basis_points has a int64 type
# asset_contract.opensea_seller_fee_basis_points has a int64 type
# asset_contract.buyer_fee_basis_points has a int64 type
# asset_contract.seller_fee_basis_points has a int64 type
# asset_contract.payout_address has a object type
# collection.banner_image_url has a object type
# collection.chat_url has a object type
# collection.created_date has a datetime64[ns] type
# collection.default_to_fiat has a bool type
# collection.description has a object type
# collection.dev_buyer_fee_basis_points has a int64 type
# collection.dev_seller_fee_basis_points has a int64 type
# collection.discord_url has a object type
# collection.display_data.card_display_style has a object type
# collection.external_url has a object type
# collection.featured has a bool type
# collection.featured_image_url has a object type
# collection.hidden has a bool type
# collection.safelist_request_status has a object type
# collection.image_url has a object type
# collection.is_subject_to_whitelist has a bool type
# collection.large_image_url has a object type
# collection.medium_username has a object type
# collection.name has a object type
# collection.only_proxied_transfers has a bool type
# collection.opensea_buyer_fee_basis_points has a int64 type
# collection.opensea_seller_fee_basis_points has a int64 type
# collection.payout_address has a object type
# collection.require_email has a bool type
# collection.short_description has a object type
# collection.slug has a object type
# collection.telegram_url has a object type
# collection.twitter_username has a object type
# collection.instagram_username has a object type
# collection.wiki_url has a object type
# owner.user.username has a object type
# owner.profile_img_url has a object type
# owner.address has a object type
# owner.config has a object type
# creator.user.username has a object type
# creator.profile_img_url has a object type
# creator.address has a object type
# creator.config has a object type
# last_sale.asset.token_id has a object type
# last_sale.asset.decimals has a float64 type
# last_sale.asset_bundle has a float64 type
# last_sale.event_type has a object type
# last_sale.event_timestamp has a object type
# last_sale.auction_type has a object type
# last_sale.total_price has a object type
# last_sale.payment_token.id has a float64 type
# last_sale.payment_token.symbol has a object type
# last_sale.payment_token.address has a object type
# last_sale.payment_token.image_url has a object type
# last_sale.payment_token.name has a object type
# last_sale.payment_token.decimals has a float64 type
# last_sale.payment_token.eth_price has a float64 type
# last_sale.payment_token.usd_price has a float64 type
# last_sale.transaction.block_hash has a object type
# last_sale.transaction.block_number has a float64 type
# last_sale.transaction.from_account.user.username has a object type
# last_sale.transaction.from_account.profile_img_url has a object type
# last_sale.transaction.from_account.address has a object type
# last_sale.transaction.from_account.config has a object type
# last_sale.transaction.id has a float64 type
# last_sale.transaction.timestamp has a object type
# last_sale.transaction.to_account.user.username has a object type
# last_sale.transaction.to_account.profile_img_url has a object type
# last_sale.transaction.to_account.address has a object type
# last_sale.transaction.to_account.config has a object type
# last_sale.transaction.transaction_hash has a object type
# last_sale.transaction.transaction_index has a float64 type
# last_sale.created_date has a object type
# last_sale.quantity has a float64 type
# creator has a float64 type
# last_sale.transaction.from_account.user has a float64 type
# last_sale.transaction.to_account.user has a float64 type
# owner.user has a float64 type
# creator.user has a float64 type
# collection.display_data.images has a object type
# last_sale has a float64 type
# transfer_fee_payment_token.id has a float64 type
# transfer_fee_payment_token.symbol has a object type
# transfer_fee_payment_token.address has a object type
# transfer_fee_payment_token.image_url has a object type
# transfer_fee_payment_token.name has a object type
# transfer_fee_payment_token.decimals has a float64 type
# transfer_fee_payment_token.eth_price has a float64 type
# transfer_fee_payment_token.usd_price has a float64 type

# %%
# we need to drop some column for better analysis. for now mostly links and urls

# %%
rev_nft = nft_sale_df.drop(['Unnamed: 0', 'image_url', 'image_preview_url', 'image_thumbnail_url', 'image_original_url',
                 'animation_url', 'animation_original_url', 'external_link', 'asset_contract.external_link',
                  'asset_contract.image_url','collection.banner_image_url', 'collection.large_image_url', 'collection.wiki_url',
                 'owner.profile_img_url', 'last_sale.payment_token.image_url', 'last_sale.transaction.from_account.profile_img_url',
                 'last_sale.transaction.to_account.profile_img_url', 'collection.display_data.images', 'transfer_fee_payment_token.image_url'],
                axis=1)

# %%
rev_nft.shape
# Out:
# (14461, 111)

# %% [markdown]
# We need to find realtionships between the null and the target variable, however we have no target variable.

# %% [markdown]
# ### Engineering Target Variable

# %% [markdown]
# This data is divided into few part:
# - Sales information (target)
# - Assets infomation (predictors)
# - collection information (predictors)
# - Creators attribute

# %%
# since we are predicting in regards to sales we analyse all sales columns

# %%
rev_nft['num_sales'].isna().value_counts()
# Out:
# False    14461
# Name: num_sales, dtype: int64

# %%
rev_nft['sell_orders'].isna().value_counts()
# Out:
# True     8216
# False    6245
# Name: sell_orders, dtype: int64

# %%
rev_nft['last_sale.event_type'].isna().value_counts()
# Out:
# True     10277
# False     4184
# Name: last_sale.event_type, dtype: int64

# %%
rev_nft['is_presale'].isna().value_counts()
# Out:
# False    14461
# Name: is_presale, dtype: int64

# %%
# join the 3 columns into one for the target variable
len(rev_nft[(rev_nft['num_sales'] > 0) |
            (rev_nft['sell_orders'].notna()) | 
            (rev_nft['last_sale.event_type'].notna())])/len(rev_nft)
# Out:
# 0.66800359587857

# %%
# create a target columns

# %%
rev_nft['target'] = np.where((rev_nft['num_sales'] > 0) |
            (rev_nft['sell_orders'].notna()) | 
            (rev_nft['last_sale.event_type'].notna()), 1, 0)

# %%
rev_nft.target.value_counts()
# Out:
# 1    9660
# 0    4801
# Name: target, dtype: int64

# %%
# we can drop the columns ['num_sales', 'sell_orders', 'last_sale.event_type'] once we have a target

# %%
rev_nft_df = rev_nft.drop(labels = ['num_sales', 'sell_orders', 'last_sale.event_type'], axis=1)
# rev_nft_df.head()

# %% [markdown]
# ### Exploring the data

# %%
rev_nft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14461 entries, 0 to 14460
# Columns: 109 entries, id to target
# dtypes: bool(9), datetime64[ns](3), float64(25), int64(12), object(60)
# memory usage: 11.2+ MB

# %%
rev_nft_df.describe()
# Out:
#                  id  decimals  top_bid  transfer_fee_payment_token  \
# count  1.446100e+04    4000.0      0.0                         0.0
# mean   6.189012e+07       0.0      NaN                         NaN
# std    4.724710e+07       0.0      NaN                         NaN
# min    1.787230e+05       0.0      NaN                         NaN
# 25%    1.706683e+07       0.0      NaN                         NaN
# 50%    5.714872e+07       0.0      NaN                         NaN
# 75%    1.118344e+08       0.0      NaN                         NaN
# max    1.190305e+08       0.0      NaN                         NaN
#
#        asset_contract.owner  asset_contract.total_supply  \
# count          1.165900e+04                  1328.000000
# mean           1.352265e+07                   137.871235
# std            2.972555e+07                  1146.537191
# min            1.000000e+02                     0.000000
# 25%            1.023840e+05                     0.000000
# 50%            1.023840e+05                     0.000000
# 75%            1.139878e+06                     0.000000
# max            1.452623e+08                 10333.000000
#
#        asset_contract.dev_buyer_fee_basis_points  \
# count                                    14461.0
# mean                                         0.0
# std                                          0.0
# min                                          0.0
# 25%                                          0.0
# 50%                                          0.0
# 75%                                          0.0
# max                                          0.0
#
#        asset_contract.dev_seller_fee_basis_points  \
# count                                14461.000000
# mean                                   136.289676
# std                                    247.061572
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                    250.000000
# max                                   1250.000000
#
#        asset_contract.opensea_buyer_fee_basis_points  \
# count                                        14461.0
# mean                                             0.0
# std                                              0.0
# min                                              0.0
# 25%                                              0.0
# 50%                                              0.0
# 75%                                              0.0
# max                                              0.0
#
#        asset_contract.opensea_seller_fee_basis_points  ...  \
# count                                    14461.000000  ...
# mean                                       249.861697  ...
# std                                          5.878692  ...
# min                                          0.000000  ...
# 25%                                        250.000000  ...
# 50%                                        250.000000  ...
# 75%                                        250.000000  ...
# max                                        250.000000  ...
#
#        last_sale.transaction.from_account.user  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        last_sale.transaction.to_account.user  owner.user  creator.user  \
# count                                    0.0         0.0           0.0
# mean                                     NaN         NaN           NaN
# std                                      NaN         NaN           NaN
# min                                      NaN         NaN           NaN
# 25%                                      NaN         NaN           NaN
# 50%                                      NaN         NaN           NaN
# 75%                                      NaN         NaN           NaN
# max                                      NaN         NaN           NaN
#
#        last_sale  transfer_fee_payment_token.id  \
# count        0.0                           19.0
# mean         NaN                           18.0
# std          NaN                            0.0
# min          NaN                           18.0
# 25%          NaN                           18.0
# 50%          NaN                           18.0
# 75%          NaN                           18.0
# max          NaN                           18.0
#
#        transfer_fee_payment_token.decimals  \
# count                                 19.0
# mean                                  18.0
# std                                    0.0
# min                                   18.0
# 25%                                   18.0
# 50%                                   18.0
# 75%                                   18.0
# max                                   18.0
#
#        transfer_fee_payment_token.eth_price  \
# count                          1.900000e+01
# mean                           1.453979e-03
# std                            2.227824e-19
# min                            1.453979e-03
# 25%                            1.453979e-03
# 50%                            1.453979e-03
# 75%                            1.453979e-03
# max                            1.453979e-03
#
#        transfer_fee_payment_token.usd_price        target
# count                          1.900000e+01  14461.000000
# mean                           3.830000e+00      0.668004
# std                            4.562583e-16      0.470946
# min                            3.830000e+00      0.000000
# 25%                            3.830000e+00      0.000000
# 50%                            3.830000e+00      1.000000
# 75%                            3.830000e+00      1.000000
# max                            3.830000e+00      1.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# ### Numerical Variables in Data

# %%
nft_num = [num for num in rev_nft_df.columns if rev_nft_df[num].dtypes not in ['O', 'bool']]

print(f"The length of numerical variable:{len(nft_num)}")

rev_nft_df[nft_num].head()
# Out:
# The length of numerical variable:40
#          id  decimals  top_bid listing_date  transfer_fee_payment_token  \
# 0  44596334       NaN      NaN          NaT                         NaN
# 1  48159964       NaN      NaN          NaT                         NaN
# 2  76676445       0.0      NaN          NaT                         NaN
# 3  62163700       NaN      NaN          NaT                         NaN
# 4  55436079       NaN      NaN          NaT                         NaN
#
#   asset_contract.created_date  asset_contract.owner  \
# 0  2021-09-03 04:01:42.829914             2504088.0
# 1  2021-09-09 15:40:47.108114            82251339.0
# 2  2021-10-20 18:56:15.301204            92620665.0
# 3  2021-04-05 12:27:21.409843            25897811.0
# 4  2021-09-17 04:51:21.073075            80258991.0
#
#    asset_contract.total_supply  asset_contract.dev_buyer_fee_basis_points  \
# 0                          NaN                                          0
# 1                          NaN                                          0
# 2                          3.0                                          0
# 3                          NaN                                          0
# 4                          NaN                                          0
#
#    asset_contract.dev_seller_fee_basis_points  ...  \
# 0                                        1000  ...
# 1                                         638  ...
# 2                                         750  ...
# 3                                         500  ...
# 4                                         500  ...
#
#    last_sale.transaction.from_account.user  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    last_sale.transaction.to_account.user  owner.user  creator.user last_sale  \
# 0                                    NaN         NaN           NaN       NaN
# 1                                    NaN         NaN           NaN       NaN
# 2                                    NaN         NaN           NaN       NaN
# 3                                    NaN         NaN           NaN       NaN
# 4                                    NaN         NaN           NaN       NaN
#
#    transfer_fee_payment_token.id  transfer_fee_payment_token.decimals  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    transfer_fee_payment_token.eth_price  transfer_fee_payment_token.usd_price  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#
# [5 rows x 40 columns]

# %%
nft_year = [time for time in nft_num if 'date' in time or 'year' in time]
nft_year
# Out:
# ['listing_date', 'asset_contract.created_date', 'collection.created_date']

# %%
# analyse the date in regard to the target, to see if there's relationship

rev_nft_df.groupby('collection.created_date')['target'].median()
# Out:
# collection.created_date
# 2019-04-26 22:13:02.062867    1.0
# 2019-04-26 22:13:02.287359    1.0
# 2019-04-26 22:13:04.207050    1.0
# 2019-04-26 22:13:06.773965    1.0
# 2019-04-26 22:13:09.153813    1.0
#                              ...
# 2021-11-25 16:31:56.117158    0.0
# 2021-11-25 16:32:04.528546    0.0
# 2021-11-25 16:32:12.821220    0.0
# 2021-11-26 06:18:23.098253    1.0
# 2021-11-26 15:02:18.348698    1.0
# Name: target, Length: 2164, dtype: float64

# %% [markdown]
# #### For float variable

# %%
nft_float = [col for col in rev_nft_df.columns if rev_nft_df[col].dtypes == 'float64']
print(f"The length of boolean variable:{len(nft_float)}")

rev_nft_df[nft_float].head()
# Out:
# The length of boolean variable:25
#    decimals  top_bid  transfer_fee_payment_token  asset_contract.owner  \
# 0       NaN      NaN                         NaN             2504088.0
# 1       NaN      NaN                         NaN            82251339.0
# 2       0.0      NaN                         NaN            92620665.0
# 3       NaN      NaN                         NaN            25897811.0
# 4       NaN      NaN                         NaN            80258991.0
#
#    asset_contract.total_supply  last_sale.asset.decimals  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          3.0                       0.0
# 3                          NaN                       NaN
# 4                          NaN                       NaN
#
#    last_sale.asset_bundle  last_sale.payment_token.id  \
# 0                     NaN                         1.0
# 1                     NaN                         1.0
# 2                     NaN                         1.0
# 3                     NaN                         1.0
# 4                     NaN                         1.0
#
#    last_sale.payment_token.decimals  last_sale.payment_token.eth_price  \
# 0                              18.0                                1.0
# 1                              18.0                                1.0
# 2                              18.0                                1.0
# 3                              18.0                                1.0
# 4                              18.0                                1.0
#
#    last_sale.payment_token.usd_price  last_sale.transaction.block_number  \
# 0                             4043.6                          13692860.0
# 1                             4043.6                          13692543.0
# 2                             4043.6                          13467549.0
# 3                             4043.6                          13692924.0
# 4                             4043.6                          13691661.0
#
#    last_sale.transaction.id  last_sale.transaction.transaction_index  \
# 0               209813729.0                                    214.0
# 1               209770332.0                                    267.0
# 2               186047015.0                                    254.0
# 3               209822255.0                                    164.0
# 4               209651027.0                                    191.0
#
#    last_sale.quantity  creator  last_sale.transaction.from_account.user  \
# 0                 1.0      NaN                                      NaN
# 1                 1.0      NaN                                      NaN
# 2                 1.0      NaN                                      NaN
# 3                 1.0      NaN                                      NaN
# 4                 1.0      NaN                                      NaN
#
#    last_sale.transaction.to_account.user  owner.user  creator.user  last_sale  \
# 0                                    NaN         NaN           NaN        NaN
# 1                                    NaN         NaN           NaN        NaN
# 2                                    NaN         NaN           NaN        NaN
# 3                                    NaN         NaN           NaN        NaN
# 4                                    NaN         NaN           NaN        NaN
#
#    transfer_fee_payment_token.id  transfer_fee_payment_token.decimals  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#    transfer_fee_payment_token.eth_price  transfer_fee_payment_token.usd_price
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN

# %%
# find the realationship between the float variable and the target
for feat in nft_float:
    data = rev_nft_df.copy()
    data.groupby(feat)['target'].hist()
    plt.xlabel(feat)
    plt.ylabel('count')
    plt.title(feat)
    plt.show()

# %%
rev_nft_df['asset_contract.seller_fee_basis_points'].value_counts()
# Out:
# 250     9830
# 500     2751
# 750      867
# 1250     539
# 1000     250
# 850       50
# 950       30
# 1138      22
# 650       22
# 550       22
# 450       19
# 350       17
# 1500      10
# 600        9
# 800        6
# 940        6
# 1200       2
# 1050       1
# 730        1
# 670        1
# 540        1
# 900        1
# 640        1
# 625        1
# 888        1
# 916        1
# Name: asset_contract.seller_fee_basis_points, dtype: int64

# %% [markdown]
# ### Object Variable

# %%
nft_cat = [cat for cat in rev_nft_df.columns if rev_nft_df[cat].dtypes == 'O']

print(f"The length of numerical variable:{len(nft_cat)}")

rev_nft_df[nft_cat].head()
# Out:
# The length of numerical variable:60
#   token_id background_color                                name  \
# 0        1              NaN                                Page
# 1      888              NaN                         888 Genesis
# 2        0              NaN  Personality Pod - Level 1 - X/8008
# 3    10004              NaN    Metakey: Edition 4 - The Captain
# 4        2              NaN           Public Sale Mint Passport
#
#                                          description  \
# 0                                         AB AETERNO
# 1  8,888 Editions of the Genesis NFT from @crypto...
# 2  You can buy one of the 8008 Intelligence Level...
# 3  Metakey: Edition 4 - The Captain (Artist - Jma...
# 4  NFT reservation system from UltraDAO, redeemab...
#
#                                            permalink  \
# 0  https://opensea.io/assets/0xa7206d878c5c387182...
# 1  https://opensea.io/assets/0x36d30b3b85255473d2...
# 2  https://opensea.io/assets/0x86758d1c5ab95ff324...
# 3  https://opensea.io/assets/0x10daa9f4c0f985430f...
# 4  https://opensea.io/assets/0xe885d519025348e301...
#
#                                       token_metadata  \
# 0  https://arweave.net/Fx_J8h0B1q6BQYBEeB2bi2Cp4k...
# 1  https://arweave.net/8qA0llVrlpgEWyD_jkqjVJqJfM...
# 2      https://metadata.alethea.ai/opensea-factory/0
# 3  https://ipfs.io/ipfs/QmTLKioirucZA9z3P23AqPo1D...
# 4  https://ipfs.io/ipfs/QmU4ng6Nynq8PemD3cW55pErK...
#
#                                               traits transfer_fee  \
# 0                                                 []
# 1  [{'trait_type': 'Artist', 'value': '888', 'dis...
# 2  [{'trait_type': 'Generation', 'value': 1, 'dis...
# 3  [{'trait_type': 'Edition', 'value': '4', 'disp...
# 4  [{'trait_type': 'Redeems', 'value': '1 Woodie'...
#
#                        asset_contract.address  \
# 0  0xa7206d878c5c3871826dfdb42191c49b1d11f466
# 1  0x36d30b3b85255473d27dd0f7fd8f35e36a9d6f06
# 2  0x86758d1c5ab95ff324f7e0b2cdec38c86eebe768
# 3  0x10daa9f4c0f985430fde4959adb2c791ef2ccf83
# 4  0xe885d519025348e30174a218be3e3e4754222860
#
#   asset_contract.asset_contract_type    asset_contract.name  \
# 0                      semi-fungible  Unidentified contract
# 1                      semi-fungible  Unidentified contract
# 2                       non-fungible   iNFT Personality Pod
# 3                      semi-fungible           The Meta Key
# 4                      semi-fungible  Woodies Mint Passport
#
#   asset_contract.nft_version asset_contract.opensea_version  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        3.0                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#   asset_contract.schema_name asset_contract.symbol  \
# 0                    ERC1155                   NaN
# 1                    ERC1155                   NaN
# 2                     ERC721                   POD
# 3                    ERC1155               MetaKey
# 4                    ERC1155           WOODIESPASS
#
#                           asset_contract.description  \
# 0                                       ∴ AB AETERNO
# 1  8888 Editions of the Genesis NFT from 888 to c...
# 2  Bring your NFT to life using a iNFT Personalit...
# 3  Metakey is an experiment exploring the unlimit...
# 4  The Official Woodies Mint Passport collection....
#
#                 asset_contract.payout_address collection.chat_url  \
# 0  0x8e8717dcd1687080757cb513d7d6702625973be8                 NaN
# 1  0x716eb921f3b346d2c5749b5380dc740d359055d7                 NaN
# 2  0x0738f702d1a7364d356729cb8845701885c487a1                 NaN
# 3  0x00ae58bfbf16260832309e1e71d84fc1b78bd6f5                 NaN
# 4  0xe70e823e77d87ee06f573587555fccb6c337e9f5                 NaN
#
#                               collection.description  \
# 0                                       ∴ AB AETERNO
# 1  8888 Editions of the Genesis NFT from 888 to c...
# 2  Bring your NFT to life using a iNFT Personalit...
# 3  Metakey is an experiment exploring the unlimit...
# 4  The Official Woodies Mint Passport collection....
#
#                  collection.discord_url  \
# 0                                   NaN
# 1             https://discord.gg/888tnw
# 2          https://discord.gg/aletheaai
# 3  https://discord.gg/invite/47tfHj4huW
# 4         https://discord.gg/qNJXDazETQ
#
#   collection.display_data.card_display_style  \
# 0                                      cover
# 1                                    contain
# 2                                      cover
# 3                                    contain
# 4                                    contain
#
#                              collection.external_url  \
# 0                             https://lostpoets.xyz/
# 1                                                NaN
# 2                                https://alethea.ai/
# 3  https://app.rarible.com/collection/0x10daa9f4c...
# 4                             https://woodiesnft.com
#
#                        collection.featured_image_url  \
# 0  https://lh3.googleusercontent.com/VNQfgH6h0cui...
# 1  https://lh3.googleusercontent.com/pnJeSudJAfhA...
# 2  https://lh3.googleusercontent.com/o_J0Y2buN6O-...
# 3  https://lh3.googleusercontent.com/qGyzQm5D9xqG...
# 4  https://lh3.googleusercontent.com/nK9T6XBYrvyQ...
#
#   collection.safelist_request_status  \
# 0                           verified
# 1                           verified
# 2                           verified
# 3                           verified
# 4                           verified
#
#                                 collection.image_url  \
# 0  https://lh3.googleusercontent.com/cGKkMxKQ-7J0...
# 1  https://lh3.googleusercontent.com/pnJeSudJAfhA...
# 2  https://lh3.googleusercontent.com/0LsJSNxzhiXQ...
# 3  https://lh3.googleusercontent.com/qGyzQm5D9xqG...
# 4  https://lh3.googleusercontent.com/N-fAM0u4qa-1...
#
#   collection.medium_username            collection.name  \
# 0                        NaN                  LOSTPOETS
# 1                        NaN           888 inner circle
# 2                        NaN  iNFT Personality Pod Sale
# 3                    metakey               The Meta Key
# 4                        NaN      Woodies Mint Passport
#
#                     collection.payout_address collection.short_description  \
# 0  0x8e8717dcd1687080757cb513d7d6702625973be8                          NaN
# 1  0x716eb921f3b346d2c5749b5380dc740d359055d7                          NaN
# 2  0x0738f702d1a7364d356729cb8845701885c487a1                          NaN
# 3  0x00ae58bfbf16260832309e1e71d84fc1b78bd6f5                          NaN
# 4  0xe70e823e77d87ee06f573587555fccb6c337e9f5                          NaN
#
#              collection.slug collection.telegram_url  \
# 0                  lostpoets                     NaN
# 1             888innercircle                     NaN
# 2  inft-personality-pod-sale                     NaN
# 3               the-meta-key                     NaN
# 4      woodies-mint-passport                     NaN
#
#   collection.twitter_username collection.instagram_username  \
# 0                   poetslost                           NaN
# 1             crypto888crypto                           NaN
# 2                real_alethea                           NaN
# 3                  themetakey                           NaN
# 4                  WoodiesNFT                           NaN
#
#   owner.user.username                               owner.address  \
# 0         NullAddress  0x0000000000000000000000000000000000000000
# 1         NullAddress  0x0000000000000000000000000000000000000000
# 2          Alethea_AI  0x0738f702d1a7364d356729cb8845701885c487a1
# 3         NullAddress  0x0000000000000000000000000000000000000000
# 4         NullAddress  0x0000000000000000000000000000000000000000
#
#   owner.config creator.user.username  \
# 0          NaN                   pak
# 1          NaN        888innercircle
# 2          NaN            Alethea_AI
# 3          NaN            TheMetakey
# 4          NaN     UltraDAO_Deployer
#
#                              creator.profile_img_url  \
# 0  https://storage.googleapis.com/opensea-static/...
# 1  https://storage.googleapis.com/opensea-static/...
# 2  https://storage.googleapis.com/opensea-static/...
# 3  https://storage.googleapis.com/opensea-static/...
# 4  https://storage.googleapis.com/opensea-static/...
#
#                               creator.address creator.config  \
# 0  0x2ce780d7c743a57791b835a9d6f998b15bbba5a4       verified
# 1  0x3660f30b87d19a30974db4fe527e45fe57a70dea            NaN
# 2  0x0738f702d1a7364d356729cb8845701885c487a1            NaN
# 3  0x00ae58bfbf16260832309e1e71d84fc1b78bd6f5            NaN
# 4  0x7e6a74008e1b8df0c5754436d0de3654636b2bf9            NaN
#
#   last_sale.asset.token_id last_sale.event_timestamp last_sale.auction_type  \
# 0                        1       2021-11-27T00:25:24                    NaN
# 1                      888       2021-11-26T23:08:15                    NaN
# 2                        0       2021-10-22T12:58:13                    NaN
# 3                    10004       2021-11-27T00:40:02                    NaN
# 4                        2       2021-11-26T19:35:55                    NaN
#
#   last_sale.total_price last_sale.payment_token.symbol  \
# 0    490000000000000000                            ETH
# 1    399900000000000000                            ETH
# 2    100000000000000000                            ETH
# 3    260000000000000000                            ETH
# 4    275000000000000000                            ETH
#
#               last_sale.payment_token.address last_sale.payment_token.name  \
# 0  0x0000000000000000000000000000000000000000                        Ether
# 1  0x0000000000000000000000000000000000000000                        Ether
# 2  0x0000000000000000000000000000000000000000                        Ether
# 3  0x0000000000000000000000000000000000000000                        Ether
# 4  0x0000000000000000000000000000000000000000                        Ether
#
#                     last_sale.transaction.block_hash  \
# 0  0xb2fadaf6b1fd00d68195086b85e27b9120d45427814b...
# 1  0x49963a6291a944f4dddd5b8d7ef451c621b7b66c4c9a...
# 2  0x861731d6a684ef1042cf0fcc0a40a52d245556c902c4...
# 3  0x3d6a97dc9507c3b3488273be01c8d9a00e277e23132c...
# 4  0x59f53453c9c2a278c28f237702af762852f0da7c695c...
#
#   last_sale.transaction.from_account.user.username  \
# 0                                         davidne0
# 1                                       Jimbolimbo
# 2                                           0xbd71
# 3                                         RoXsaita
# 4                                          Kagawa7
#
#    last_sale.transaction.from_account.address  \
# 0  0x51814118035cfa6a5f0e8ee7f5b581c3095c6c53
# 1  0x0dfd069770dfd14408f2c3420d12d7402e92fa77
# 2  0xbd717a7ce98b22b085388411be80ff007f0fb828
# 3  0x8640ae66adc5f24a957ee08b96dd681a4a668c0a
# 4  0x5514ca4a85dfb69341d7c1f76db2610c7e742e80
#
#   last_sale.transaction.from_account.config last_sale.transaction.timestamp  \
# 0                                       NaN             2021-11-27T00:25:24
# 1                                       NaN             2021-11-26T23:08:15
# 2                                       NaN             2021-10-22T12:58:13
# 3                                       NaN             2021-11-27T00:40:02
# 4                                       NaN             2021-11-26T19:35:55
#
#   last_sale.transaction.to_account.user.username  \
# 0                                 OpenSea-Orders
# 1                                 OpenSea-Orders
# 2                                 OpenSea-Orders
# 3                                 OpenSea-Orders
# 4                                 OpenSea-Orders
#
#      last_sale.transaction.to_account.address  \
# 0  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# 1  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# 2  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# 3  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
# 4  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b
#
#   last_sale.transaction.to_account.config  \
# 0                                verified
# 1                                verified
# 2                                verified
# 3                                verified
# 4                                verified
#
#               last_sale.transaction.transaction_hash  \
# 0  0x77c5ac229ebdafce9a915c81104432028027f8313939...
# 1  0x8ef7ff825fc154e1abf0e024244b903eb6ab86ad8fe6...
# 2  0x0b726d1464767befbd20a7a81139e9b1722a4ae605f4...
# 3  0xe84f867309a41447a02735fee990822a6e5f084931c8...
# 4  0xeda61b6f14a699afc803cd377be7331ac05c7f554590...
#
#        last_sale.created_date transfer_fee_payment_token.symbol  \
# 0  2021-11-27T00:25:42.232625                               NaN
# 1  2021-11-26T23:08:52.317888                               NaN
# 2  2021-10-22T12:58:45.100773                               NaN
# 3  2021-11-27T00:40:27.927641                               NaN
# 4  2021-11-26T19:37:03.221130                               NaN
#
#   transfer_fee_payment_token.address transfer_fee_payment_token.name
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN

# %%
for feat in nft_cat:
    print(f"The column is {feat} and number of features are {len(rev_nft_df[feat].unique())} ")
# Out:
# The column is token_id and number of features are 14461
# The column is background_color and number of features are 26
# The column is name and number of features are 11119
# The column is description and number of features are 8115
# The column is permalink and number of features are 14461
# The column is token_metadata and number of features are 5827
# The column is traits and number of features are 6723
# The column is transfer_fee and number of features are 7
# The column is asset_contract.address and number of features are 454
# The column is asset_contract.asset_contract_type and number of features are 2
# The column is asset_contract.name and number of features are 433
# The column is asset_contract.nft_version and number of features are 4
# The column is asset_contract.opensea_version and number of features are 2
# The column is asset_contract.schema_name and number of features are 3
# The column is asset_contract.symbol and number of features are 401
# The column is asset_contract.description and number of features are 406
# The column is asset_contract.payout_address and number of features are 356
# The column is collection.chat_url and number of features are 2
# The column is collection.description and number of features are 1724
# The column is collection.discord_url and number of features are 681
# The column is collection.display_data.card_display_style and number of features are 4
# The column is collection.external_url and number of features are 957
# The column is collection.featured_image_url and number of features are 1424
# The column is collection.safelist_request_status and number of features are 4
# The column is collection.image_url and number of features are 1841
# The column is collection.medium_username and number of features are 140
# The column is collection.name and number of features are 2171
# The column is collection.payout_address and number of features are 1505
# The column is collection.short_description and number of features are 5
# The column is collection.slug and number of features are 2171
# The column is collection.telegram_url and number of features are 122
# The column is collection.twitter_username and number of features are 1204
# The column is collection.instagram_username and number of features are 669
# The column is owner.user.username and number of features are 991
# The column is owner.address and number of features are 4085
# The column is owner.config and number of features are 3
# The column is creator.user.username and number of features are 2096
# The column is creator.profile_img_url and number of features are 34
# The column is creator.address and number of features are 2539
# The column is creator.config and number of features are 4
# The column is last_sale.asset.token_id and number of features are 4185
# The column is last_sale.event_timestamp and number of features are 4107
# The column is last_sale.auction_type and number of features are 2
# The column is last_sale.total_price and number of features are 741
# The column is last_sale.payment_token.symbol and number of features are 18
# The column is last_sale.payment_token.address and number of features are 18
# The column is last_sale.payment_token.name and number of features are 18
# The column is last_sale.transaction.block_hash and number of features are 4107
# The column is last_sale.transaction.from_account.user.username and number of features are 2704
# The column is last_sale.transaction.from_account.address and number of features are 3528
# The column is last_sale.transaction.from_account.config and number of features are 4
# The column is last_sale.transaction.timestamp and number of features are 4107
# The column is last_sale.transaction.to_account.user.username and number of features are 2
# The column is last_sale.transaction.to_account.address and number of features are 13
# The column is last_sale.transaction.to_account.config and number of features are 2
# The column is last_sale.transaction.transaction_hash and number of features are 4184
# The column is last_sale.created_date and number of features are 4185
# The column is transfer_fee_payment_token.symbol and number of features are 2
# The column is transfer_fee_payment_token.address and number of features are 2
# The column is transfer_fee_payment_token.name and number of features are 2

# %% [markdown]
# ### Exploring the assets class columns

# %%
rev_nft_df['asset_contract.name'].value_counts(normalize=True)
# Out:
# OpenSea Collection             0.545260
# Dodgers MLB Crypto             0.167762
# Rarible 1155                   0.069152
# Hero                           0.041837
# parallel                       0.011756
#                                  ...
# RiverMen                       0.000069
# BoredApeKennelClub             0.000069
# Unicode (for Geeks)            0.000069
# DeHorizon                      0.000069
# Beeple Round 2 Open Edition    0.000069
# Name: asset_contract.name, Length: 433, dtype: float64

# %%
rev_nft_df['asset_contract.schema_name'].value_counts()
# Out:
# ERC1155        9729
# ERC721         4728
# CRYPTOPUNKS       4
# Name: asset_contract.schema_name, dtype: int64

# %%
nft_asset = [asset for asset in rev_nft_df if 'asset_contract' in asset]
# rev_nft_df[nft_asset].head()
# Out:
#                        asset_contract.address  \
# 0  0xa7206d878c5c3871826dfdb42191c49b1d11f466
# 1  0x36d30b3b85255473d27dd0f7fd8f35e36a9d6f06
# 2  0x86758d1c5ab95ff324f7e0b2cdec38c86eebe768
# 3  0x10daa9f4c0f985430fde4959adb2c791ef2ccf83
# 4  0xe885d519025348e30174a218be3e3e4754222860
#
#   asset_contract.asset_contract_type asset_contract.created_date  \
# 0                      semi-fungible  2021-09-03 04:01:42.829914
# 1                      semi-fungible  2021-09-09 15:40:47.108114
# 2                       non-fungible  2021-10-20 18:56:15.301204
# 3                      semi-fungible  2021-04-05 12:27:21.409843
# 4                      semi-fungible  2021-09-17 04:51:21.073075
#
#      asset_contract.name asset_contract.nft_version  \
# 0  Unidentified contract                        NaN
# 1  Unidentified contract                        NaN
# 2   iNFT Personality Pod                        3.0
# 3           The Meta Key                        NaN
# 4  Woodies Mint Passport                        NaN
#
#   asset_contract.opensea_version  asset_contract.owner  \
# 0                            NaN             2504088.0
# 1                            NaN            82251339.0
# 2                            NaN            92620665.0
# 3                            NaN            25897811.0
# 4                            NaN            80258991.0
#
#   asset_contract.schema_name asset_contract.symbol  \
# 0                    ERC1155                   NaN
# 1                    ERC1155                   NaN
# 2                     ERC721                   POD
# 3                    ERC1155               MetaKey
# 4                    ERC1155           WOODIESPASS
#
#    asset_contract.total_supply  \
# 0                          NaN
# 1                          NaN
# 2                          3.0
# 3                          NaN
# 4                          NaN
#
#                           asset_contract.description  \
# 0                                       ∴ AB AETERNO
# 1  8888 Editions of the Genesis NFT from 888 to c...
# 2  Bring your NFT to life using a iNFT Personalit...
# 3  Metakey is an experiment exploring the unlimit...
# 4  The Official Woodies Mint Passport collection....
#
#    asset_contract.default_to_fiat  asset_contract.dev_buyer_fee_basis_points  \
# 0                           False                                          0
# 1                           False                                          0
# 2                           False                                          0
# 3                           False                                          0
# 4                           False                                          0
#
#    asset_contract.dev_seller_fee_basis_points  \
# 0                                        1000
# 1                                         638
# 2                                         750
# 3                                         500
# 4                                         500
#
#    asset_contract.only_proxied_transfers  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    asset_contract.opensea_buyer_fee_basis_points  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    asset_contract.opensea_seller_fee_basis_points  \
# 0                                             250
# 1                                             250
# 2                                             250
# 3                                             250
# 4                                             250
#
#    asset_contract.buyer_fee_basis_points  \
# 0                                      0
# 1                                      0
# 2                                      0
# 3                                      0
# 4                                      0
#
#    asset_contract.seller_fee_basis_points  \
# 0                                    1250
# 1                                     888
# 2                                    1000
# 3                                     750
# 4                                     750
#
#                 asset_contract.payout_address
# 0  0x8e8717dcd1687080757cb513d7d6702625973be8
# 1  0x716eb921f3b346d2c5749b5380dc740d359055d7
# 2  0x0738f702d1a7364d356729cb8845701885c487a1
# 3  0x00ae58bfbf16260832309e1e71d84fc1b78bd6f5
# 4  0xe70e823e77d87ee06f573587555fccb6c337e9f5

# %%
asset_df = rev_nft_df[nft_asset]

# %%
sns.countplot(x='target', hue='asset_contract.nft_version', data=rev_nft_df,
              palette = 'RdBu_r')
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
sns.countplot(x='target', hue='asset_contract.schema_name', data=rev_nft_df,
              palette = 'rainbow')
ax.set_xlabel('target')
ax.set_ylabel('count')
# Out:
# Text(25.19999999999999, 0.5, 'count')

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.countplot(data=rev_nft_df,
              y='asset_contract.name',
              hue='target',
              order=rev_nft_df['asset_contract.name'].value_counts().iloc[:10].index, 
              palette = 'rainbow',
              ax=ax)
sns.set_style("white")
fig.suptitle('Assets Owners', fontsize=25)
ax.set_xlabel('Count', fontsize=19)
ax.set_ylabel('Collection', fontsize=19)
plt.legend(title='target', 
           title_fontsize = 'x-large',
           labels=['Not Sold', 'Sold'],
           fontsize="large", 
           loc='best')

# %%
for column in list(rev_nft_df.columns):
    print(f"{rev_nft_df[str(column)].isnull().sum()/len(rev_nft_df):.2%} of {column} is null")
# Out:
# 0.00% of id is null
# 0.00% of token_id is null
# 99.20% of background_color is null
# 5.28% of name is null
# 27.61% of description is null
# 0.00% of permalink is null
# 72.34% of decimals is null
# 59.71% of token_metadata is null
# 0.00% of traits is null
# 100.00% of top_bid is null
# 100.00% of listing_date is null
# 0.00% of is_presale is null
# 100.00% of transfer_fee_payment_token is null
# 0.00% of transfer_fee is null
# 0.00% of asset_contract.address is null
# 0.00% of asset_contract.asset_contract_type is null
# 0.00% of asset_contract.created_date is null
# 0.00% of asset_contract.name is null
# 67.26% of asset_contract.nft_version is null
# 45.45% of asset_contract.opensea_version is null
# 19.38% of asset_contract.owner is null
# 0.00% of asset_contract.schema_name is null
# 9.06% of asset_contract.symbol is null
# 90.82% of asset_contract.total_supply is null
# 59.59% of asset_contract.description is null
# 0.00% of asset_contract.default_to_fiat is null
# 0.00% of asset_contract.dev_buyer_fee_basis_points is null
# 0.00% of asset_contract.dev_seller_fee_basis_points is null
# 0.00% of asset_contract.only_proxied_transfers is null
# 0.00% of asset_contract.opensea_buyer_fee_basis_points is null
# 0.00% of asset_contract.opensea_seller_fee_basis_points is null
# 0.00% of asset_contract.buyer_fee_basis_points is null
# 0.00% of asset_contract.seller_fee_basis_points is null
# 67.94% of asset_contract.payout_address is null
# 99.99% of collection.chat_url is null
# 0.00% of collection.created_date is null
# 0.00% of collection.default_to_fiat is null
# 12.88% of collection.description is null
# 0.00% of collection.dev_buyer_fee_basis_points is null
# 0.00% of collection.dev_seller_fee_basis_points is null
# 57.92% of collection.discord_url is null
# 4.35% of collection.display_data.card_display_style is null
# 43.02% of collection.external_url is null
# 0.00% of collection.featured is null
# 24.69% of collection.featured_image_url is null
# 0.00% of collection.hidden is null
# 0.00% of collection.safelist_request_status is null
# 7.22% of collection.image_url is null
# 0.00% of collection.is_subject_to_whitelist is null
# 85.35% of collection.medium_username is null
# 0.00% of collection.name is null
# 0.00% of collection.only_proxied_transfers is null
# 0.00% of collection.opensea_buyer_fee_basis_points is null
# 0.00% of collection.opensea_seller_fee_basis_points is null
# 20.81% of collection.payout_address is null
# 0.00% of collection.require_email is null
# 99.91% of collection.short_description is null
# 0.00% of collection.slug is null
# 86.52% of collection.telegram_url is null
# 24.59% of collection.twitter_username is null
# 77.73% of collection.instagram_username is null
# 23.71% of owner.user.username is null
# 0.00% of owner.address is null
# 99.35% of owner.config is null
# 16.38% of creator.user.username is null
# 1.42% of creator.profile_img_url is null
# 1.42% of creator.address is null
# 91.29% of creator.config is null
# 71.07% of last_sale.asset.token_id is null
# 99.80% of last_sale.asset.decimals is null
# 100.00% of last_sale.asset_bundle is null
# 71.07% of last_sale.event_timestamp is null
# 95.64% of last_sale.auction_type is null
# 71.07% of last_sale.total_price is null
# 71.07% of last_sale.payment_token.id is null
# 71.07% of last_sale.payment_token.symbol is null
# 71.07% of last_sale.payment_token.address is null
# 71.07% of last_sale.payment_token.name is null
# 71.07% of last_sale.payment_token.decimals is null
# 71.11% of last_sale.payment_token.eth_price is null
# 71.11% of last_sale.payment_token.usd_price is null
# 71.07% of last_sale.transaction.block_hash is null
# 71.07% of last_sale.transaction.block_number is null
# 77.40% of last_sale.transaction.from_account.user.username is null
# 71.07% of last_sale.transaction.from_account.address is null
# 99.18% of last_sale.transaction.from_account.config is null
# 71.07% of last_sale.transaction.id is null
# 71.07% of last_sale.transaction.timestamp is null
# 75.49% of last_sale.transaction.to_account.user.username is null
# 71.07% of last_sale.transaction.to_account.address is null
# 75.49% of last_sale.transaction.to_account.config is null
# 71.07% of last_sale.transaction.transaction_hash is null
# 71.07% of last_sale.transaction.transaction_index is null
# 71.07% of last_sale.created_date is null
# 71.29% of last_sale.quantity is null
# 100.00% of creator is null
# 100.00% of last_sale.transaction.from_account.user is null
# 100.00% of last_sale.transaction.to_account.user is null
# 100.00% of owner.user is null
# 100.00% of creator.user is null
# 100.00% of last_sale is null
# 99.87% of transfer_fee_payment_token.id is null
# 99.87% of transfer_fee_payment_token.symbol is null
# 99.87% of transfer_fee_payment_token.address is null
# 99.87% of transfer_fee_payment_token.name is null
# 99.87% of transfer_fee_payment_token.decimals is null
# 99.87% of transfer_fee_payment_token.eth_price is null
# 99.87% of transfer_fee_payment_token.usd_price is null
# 0.00% of target is null

# %%
# selecting target columns and desired predictors

df = rev_nft_df[[ 
    # basic attributes    
    'id', 'token_id', 'name', 'traits', 'description', 'is_presale',
    
    # asset attributes
    'asset_contract.created_date', 'asset_contract.name', 'asset_contract.total_supply',
    'asset_contract.symbol', 'asset_contract.schema_name', 'asset_contract.asset_contract_type', 
    'asset_contract.nft_version', 'asset_contract.opensea_version',
    'asset_contract.seller_fee_basis_points', 'asset_contract.dev_seller_fee_basis_points',
    'asset_contract.opensea_seller_fee_basis_points', 
    
    # collection attributes
    'collection.created_date', 'collection.slug', 'collection.safelist_request_status', 'collection.featured', 
    'collection.description',
    'collection.dev_seller_fee_basis_points', 'collection.opensea_seller_fee_basis_points',
    'collection.external_url', 'collection.image_url', 'collection.twitter_username', 'collection.instagram_username', 'collection.medium_username', 'collection.chat_url', 
    
    # creator attributes
    'creator.user.username',
    
    # owner attributes
    'owner.address',
    'target'
    ]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14461 entries, 0 to 14460
# Data columns (total 33 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              14461 non-null  int64
#  1   token_id                                        14461 non-null  object
#  2   name                                            13698 non-null  object
#  3   traits                                          14461 non-null  object
#  4   description                                     10469 non-null  object
#  5   is_presale                                      14461 non-null  bool
#  6   asset_contract.created_date                     14461 non-null  datetime64[ns]
#  7   asset_contract.name                             14461 non-null  object
#  8   asset_contract.total_supply                     1328 non-null   float64
#  9   asset_contract.symbol                           13151 non-null  object
#  10  asset_contract.schema_name                      14461 non-null  object
#  11  asset_contract.asset_contract_type              14461 non-null  object
#  12  asset_contract.nft_version                      4734 non-null   object
#  13  asset_contract.opensea_version                  7888 non-null   object
#  14  asset_contract.seller_fee_basis_points          14461 non-null  int64
#  15  asset_contract.dev_seller_fee_basis_points      14461 non-null  int64
#  16  asset_contract.opensea_seller_fee_basis_points  14461 non-null  int64
#  17  collection.created_date                         14461 non-null  datetime64[ns]
#  18  collection.slug                                 14461 non-null  object
#  19  collection.safelist_request_status              14461 non-null  object
#  20  collection.featured                             14461 non-null  bool
#  21  collection.description                          12598 non-null  object
#  22  collection.dev_seller_fee_basis_points          14461 non-null  int64
#  23  collection.opensea_seller_fee_basis_points      14461 non-null  int64
#  24  collection.external_url                         8240 non-null   object
#  25  collection.image_url                            13417 non-null  object
#  26  collection.twitter_username                     10905 non-null  object
#  27  collection.instagram_username                   3220 non-null   object
#  28  collection.medium_username                      2118 non-null   object
#  29  collection.chat_url                             1 non-null      object
#  30  creator.user.username                           12092 non-null  object
#  31  owner.address                                   14461 non-null  object
#  32  target                                          14461 non-null  int64
# dtypes: bool(2), datetime64[ns](2), float64(1), int64(7), object(21)
# memory usage: 3.4+ MB

# %%
df.to_csv('revised_nft.csv')
